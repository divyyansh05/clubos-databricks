# %%
import os

BASE = "/Workspace/Users/divextra05@gmail.com/clubos-databricks"

folders = [
    "src/bronze",
    "src/silver",
    "src/gold",
    "src/analytics",
    "src/quality",
    "resources",
    "seeds",
]

for folder in folders:
    os.makedirs(f"{BASE}/{folder}", exist_ok=True)
    print(f"Created: {folder}")

# Create placeholder files so folders are not empty (Git ignores empty folders)
placeholders = [
    "src/bronze/01_ingest_internal_metrics.py",
    "src/bronze/02_ingest_benchmark_metrics.py",
    "src/silver/01_normalize_internal_metrics.py",
    "src/silver/02_normalize_benchmark_metrics.py",
    "src/gold/01_build_kpi_health.py",
    "src/gold/02_build_peer_benchmark.py",
    "src/gold/03_build_monthly_brief_inputs.py",
    "src/gold/04_build_priority_board.py",
    "src/analytics/01_validate_signals.py",
    "src/analytics/02_compute_priority_inputs.py",
    "src/quality/01_run_data_quality_checks.py",
    "seeds/metric_dictionary.json",
]

for f in placeholders:
    full_path = f"{BASE}/{f}"
    with open(full_path, "w") as fh:
        fh.write(f"# {f.split('/')[-1]} — placeholder\n")
    print(f"Created: {f}")

print("\nScaffold complete.")
